# %%
import requests
import json

url = 'https://services.swpc.noaa.gov/json/stereo/stereo_a_1m.json'
response = requests.get(url)
contents = response.json()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(contents)

# %%
df.head()
# Out:
#               timestamp  density_cm3  speed_KPS temp_K  mag_hgrtn_r_nT  \
# 0  2023-10-09T06:28:00Z          NaN        NaN   None        0.645440
# 1  2023-10-09T06:29:00Z     3.091920  342.47067   None       -0.089394
# 2  2023-10-09T06:30:00Z     3.522444  351.33859   None       -1.350774
# 3  2023-10-09T06:31:00Z          NaN        NaN   None       -1.616747
# 4  2023-10-09T06:32:00Z          NaN        NaN   None       -2.385148
#
#    mag_hgrtn_t_nT  mag_hgrtn_n_nT     Bt_nT  theta_deg     phi_deg  \
# 0       -4.615780        1.970402  5.105662  22.726665  113.024450
# 1       -4.847908        0.888636  5.020738  10.399650  100.366040
# 2       -4.973600       -0.240864  5.205403  -2.631477   87.130714
# 3       -4.672960       -0.561974  5.028303  -6.485843   82.919746
# 4       -4.288535       -1.536788  5.145087 -17.372042   70.283470
#
#    low_energy_electrons_35-65_keV  low_energy_electrons_125-255_keV  \
# 0                       14.957264                          3.205128
# 1                       18.162394                          2.218935
# 2                       11.752136                          1.725838
# 3                        7.478632                          2.712032
# 4                        9.615385                          1.725838
#
#    low_energy_protons_75-137_keV  low_energy_protons_137-623_keV  \
# 0                      89.342186                        9.279432
# 1                      74.715370                        9.229000
# 2                      51.786842                        7.110869
# 3                      60.088551                        7.917776
# 4                      52.972801                        7.665617
#
#    low_energy_protons_623-2224_keV  high_energy_protons_13-21_MeV  \
# 0                         0.428654                            0.0
# 1                         0.413345                            0.0
# 2                         0.275563                            0.0
# 3                         0.489890                            0.0
# 4                         0.290872                            0.0
#
#    high_energy_protons_40-100_MeV  lead_lag_time_days
# 0                        0.000915                 NaN
# 1                        0.000000           -0.199884
# 2                        0.000000           -0.203539
# 3                        0.000459                 NaN
# 4                        0.000000                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37813 entries, 0 to 37812
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   timestamp                         37813 non-null  object
#  1   density_cm3                       10110 non-null  float64
#  2   speed_KPS                         10110 non-null  float64
#  3   temp_K                            0 non-null      object
#  4   mag_hgrtn_r_nT                    37703 non-null  float64
#  5   mag_hgrtn_t_nT                    37703 non-null  float64
#  6   mag_hgrtn_n_nT                    37703 non-null  float64
#  7   Bt_nT                             37703 non-null  float64
#  8   theta_deg                         37703 non-null  float64
#  9   phi_deg                           37703 non-null  float64
#  10  low_energy_electrons_35-65_keV    37450 non-null  float64
#  11  low_energy_electrons_125-255_keV  37450 non-null  float64
#  12  low_energy_protons_75-137_keV     37450 non-null  float64
#  13  low_energy_protons_137-623_keV    37450 non-null  float64
#  14  low_energy_protons_623-2224_keV   37450 non-null  float64
#  15  high_energy_protons_13-21_MeV     37450 non-null  float64
#  16  high_energy_protons_40-100_MeV    37450 non-null  float64
#  17  lead_lag_time_days                10110 non-null  float64
# dtypes: float64(16), object(2)
# memory usage: 5.2+ MB

# %%
print(df['timestamp'].min())

# %%
x = df['mag_hgrtn_n_nT'].apply('abs')
x.plot()
# Out:
# <AxesSubplot:>

# %%
df['Bt_nT'].plot()
# Out:
# <AxesSubplot:>

# %%
df['density_cm3'].plot()
# Out:
# <AxesSubplot:>

# %%
df['speed_KPS'].plot()
# Out:
# <AxesSubplot:>

# %%
import pickle

with open('./data/solar_wind.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
import pandas as pd
import pickle
import numpy as np

with open('./data/solar_wind.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df['timestamp']
# Out:
# 0        2023-10-09T06:28:00Z
# 1        2023-10-09T06:29:00Z
# 2        2023-10-09T06:30:00Z
# 3        2023-10-09T06:31:00Z
# 4        2023-10-09T06:32:00Z
#                  ...
# 37808    2023-11-09T00:50:00Z
# 37809    2023-11-09T00:51:00Z
# 37810    2023-11-09T00:52:00Z
# 37811    2023-11-09T00:53:00Z
# 37812    2023-11-09T00:54:00Z
# Name: timestamp, Length: 37813, dtype: object
